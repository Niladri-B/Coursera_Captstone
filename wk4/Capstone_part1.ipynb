# %% [markdown]
# # Street-level analysis of public transport options in Oslo

# %% [markdown]
# The project will aim to :
# * extract geo-coordinates of each street address
#   * Street start address > street end address
# * Use Foursquare API to obtain:
#   * Bus routes
#   * Tram
#   * Light rail
#   * Trains
# * Cluster the transport options down to the street level and draw conclusions

# %% [markdown]
# ----
# > Jump to :
# * [Part 2](https://github.com/Niladri-B/Coursera_Captstone/blob/master/wk4/Capstone_part2.ipynb), *Extracting Foursquare Data*
# * [Part 3](https://github.com/Niladri-B/Coursera_Captstone/blob/master/wk4/Capstone_part3.ipynb) , *Exploratory Data Analysis*
# * [Part 4](https://github.com/Niladri-B/Coursera_Captstone/blob/master/wk4/Capstone_part4.ipynb), *Clustering and Visualising*
# * [Part 5](https://github.com/Niladri-B/Coursera_Captstone/blob/master/wk4/Capstone_part5.ipynb), *Conclusion & Discussion*

# %% [markdown]
# # Part I: Web Scraping of postcodes and streets

# %% [markdown]
# ## 1. Set up environment

# %%
import pandas as pd
import numpy as np
import folium
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl
import re

# %% [markdown]
# ## 2. Obtain and parse URL

# %% [markdown]
# #### 2.1 Ignore SSL errors

# %%
cntxt = ssl.create_default_context()
cntxt.check_hostname = False
cntxt.verify_mode = ssl.CERT_NONE

# %% [markdown]
# #### 2.2 Obtain URL

# %%
url = input('Please enter the website to obtain data from: ')
if len(url) < 1: url = 'https://www.erikbolstad.no/postnummer-koordinatar/kommune.php?kommunenummer=301'
print('You want data from >>>\n', url, '\n<<<')
# Out:
# Please enter the website to obtain data from:
# You want data from >>>
#  https://www.erikbolstad.no/postnummer-koordinatar/kommune.php?kommunenummer=301
# <<<

# %% [markdown]
# #### 2.3 Parse URL

# %%
#Use a file-handle like object to open the url
html = urlopen(url, context= cntxt).read() #Read slurps everything in #Note that is additional function written at end

#Use BeautifulSoup to parse
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ## 3. Explore and obtain relevant data

# %% [markdown]
# For each Postkodenummer :
# * Ignore postnummer til postboksar, postnummer til servicepostnummer, postnummer til gateadresser og postboksar
# * Obtain Lat + Lon of postnummer of gate-/veg-adresse, save in table1
# * Obtain all street names (Gate-/veg-adresse)
#   * For each streetname :
#       * Obtain Koordinatar of all addresses
#           * Extract coodinates of start address/minimum
#           * Extract coordinates of end address/last
#           * ~~Estimate street length~~
#           * Establish mid-point
#       * Save in table2

# %%
#Data is contained in the <tr> tags
#tags = soup('tr')

# %%
#Extract tags that are in use
tagsinUse = soup.find_all('tr', class_ = 'ibruk')

count = 0 #Initiate counter
dictn = {} #With postcode as KEy, and everything else as LIST of values
lisT = []

for i in tagsinUse:
    #count = count +1
    #print('\nCount: {}'.format(count))
    #if count == 5:
     #   break
          
    #Look at the parts of the tag
    #print('TAG:', i)
    #print('Postnummer:', i.th.text)#WORKS
    #print(str(i.contents))
    #print(type(str(i.contents)))
    
    if re.search('Gate-/veg-adresse', str(i.contents)):#i.e. print only if postbox belongs to gate/veg-adresse
        #For intial testing
        #count = count +1
        #if count > 5:
               # break
            
        #print('\nCount: {}'.format(count))
        #print(str(i.contents))#Convert to str is important to be able to perform regEX
        #print(i.th.a.text)#Extract postcode number
        #print(len(i.contents))#Seems to be constant length of 9 (counting from 0)
        #print(i.contents[5].a.text)#From 5th element (counting from 0, extract the lat+ long)
        #contents[7].text #Extract bydel
        
        #print(i.th.a.text,i.contents[7].text, i.contents[5].a.text)
        pinCity = i.th.a.text.split(' ')#0018 OSLO #So there is space in between, split on it
        #print(pinCity[0])
        
        #Also split the latitude and longitude
        latlon = i.contents[5].a.text.split(',')
        #print(latlon[0], latlon[1])
        #list.append(i.contents[7].text), list.append(i.contents[5].a.text)
        lisT.append(i.contents[7].text), lisT.append(latlon[0]), lisT.append(latlon[1])
        dictn[pinCity[0]] = lisT
    else:
        continue#Ignore all other instances: Postboksar/Gateadresser og postboksar/Servicepostnummer
    lisT = []

#print('\n<<<----The dictionary follows------>>>>>')
#for k,v in dict.items():
 #   print(k,v)

# %%
#Convert to dataframe
data = pd.DataFrame.from_dict(dictn, orient='index')
data.head()
# Out:
#                       0        1         2
# 0188         Gamle Oslo  59.9126   10.7608
# 0159            Sentrum  59.9139   10.7416
# 0584             Bjerke  59.9390   10.8180
# 0281             Ullern  59.9208   10.6622
# 1275  Søndre Nordstrand  59.8267   10.8379

# %%
#Make modifications on the table to make it prettier- assign column names + reset index
#Reset index
data.reset_index(inplace= True)
data.head()
# Out:
#   index                  0        1         2
# 0  0188         Gamle Oslo  59.9126   10.7608
# 1  0159            Sentrum  59.9139   10.7416
# 2  0584             Bjerke  59.9390   10.8180
# 3  0281             Ullern  59.9208   10.6622
# 4  1275  Søndre Nordstrand  59.8267   10.8379

# %%
#Change column names
data.columns.values[0:] = ['Postcode','Bydel/District','Latitude','Longitude']
data.head()
# Out:
#   Postcode     Bydel/District Latitude Longitude
# 0     0188         Gamle Oslo  59.9126   10.7608
# 1     0159            Sentrum  59.9139   10.7416
# 2     0584             Bjerke  59.9390   10.8180
# 3     0281             Ullern  59.9208   10.6622
# 4     1275  Søndre Nordstrand  59.8267   10.8379

# %%
data.shape
# Out:
# (442, 4)

# %%
data.to_csv(path_or_buf= './postCode_Bydel.csv', index = False)

# %% [markdown]
# ## 4. Obtain street-level information

# %%
def postCheck(pass_the_url):
    exceptions = ['0018','0045']
    #if (re.search(exceptions, pass_the_url) for post in exceptions):
    if [post for post in exceptions if re.search(post, pass_the_url)]:#Using List comprehension
        #if re.search(post, pass_the_url):
        print('Exceptional post found, skipping...')
        return 0
    else:
        print(pass_the_url)

# %%
import requests
#This library is superior to the urllib for parsing out non-ASCII characters such as those found in Norwegian
#r = requests.get('https://no.wikipedia.org/wiki/Jonas_Gahr_Støre')
#print(r.text)

# %%
#Small version, to test things out

#Extract tags that are in use
tagsinUse = soup.find_all('tr', class_ = 'ibruk')

count = 0 #Initiate counter
midStreetDict = dict()
midStreetLoc = list()
failedStreet = list()

for i in tagsinUse:      
    if re.search('Gate-/veg-adresse', str(i.contents)): #i.e. print only if postbox belongs to gate/veg-adresse
        
        #For intial testing
        count = count +1
        if count > 6:break
        print('\nCount: {}'.format(count))
        print('Working on postcode {}...'.format(i.th.a.text))
        posturl = i.th.a.get('href', None )#Postcode link
        postCheck(posturl)#Custom function defined above
        
        #Parse Postcode link and open it
        html2 = urllib.request.urlopen(posturl, context=cntxt)#Open, similar to filehandle
        #print('HTML2 is {}'.format(html2))
        soup2 = BeautifulSoup(html2, 'html.parser')#Parse
        #print(soup2)
        
        #Establish canonical link that will combine with street address URL to form new URL
        canonical = 'https://www.erikbolstad.no/postnummer-koordinatar/'
        
        #Extract tag in the new link
        tagsinUse2 = soup2.find_all('table', style="margin-top: 4rem;")
        for j in tagsinUse2:
            #print('\n<<<<Printing all tags selected from soup2...>>>>')
            #print(j)
            td = j.find_all('td', itemtype="https://schema.org/StreetAddress")#Find the street addresses
            #print('<<<<Printing td tags...>>>>')
            #print(td,'\n')
            #print(j.td.a.text)#Gives only 1 street address#Early version of script
            for tag in td:
                streetUrl = canonical+tag.a.get('href',None)
                streetName = tag.a.text
                print(streetUrl)
                #print('Working on:', tag.a.text,'\n')
                print('Working on:', streetName)
                
                #Parse street url link and open it
                try:
                    #html3 = urllib.request.urlopen(streetUrl, context=cntxt)#Open, similar to filehandle
                    html3 = requests.get(streetUrl).text
                    #print('HTML3 is {}'.format(html3))
                    soup3 = BeautifulSoup(html3, 'html.parser')#Parse
                
                    #Extract all anchor tags since within them one finds the street address + geocoordinates
                    streets = soup3.find_all('a')
    
                    streetList = []
                    latlonList = []
                    #latlonTup = tuple()
                    for datas in streets:
                        text = datas.text
                        #print(text) 
                        #Only get the text that is street name or lat, long
                        if re.search(streetName+'\s[0-9]+', text):# or re.findall('[0-9]+,', text):
                            #print(text)
                            streetList.append(text)
                     
                        elif re.search('[0-9]+,', text):
                            coordinates = text.split(',')
                            #print(tuple(coordinates)) #Make into latlon coordinates tuple so that it can be appended to list
                            latlonList.append(tuple(coordinates))
                        
                    #print(streetList)
                    #print(latlonList)
                    combined = dict(zip(streetList, latlonList))
                
                    #Establish mid-points of streets
                    lat2 = []
                    long2 = []
                    for l in latlonList :
                        lat2.append(float(l[0]))
                        long2.append(float(l[1]))

                    midStreetLat = sum(lat2)/len(lat2)
                    midStreetLon = sum(long2)/len(long2)
                    #midStreetLoc.append(midStreetLat,midStreetLoc)
                    print(streetName,midStreetLat, midStreetLon,'\n')
                except:
                    print('Can\'t open URL, possible UnicodeEncode error. Skipping...\n')
                    failedStreet.append(streetName)
# Out:
# Count: 1
# Working on postcode 0018 OSLO...
# Exceptional post found, skipping...
#
# Count: 2
# Working on postcode 0045 OSLO...
# Exceptional post found, skipping...
#
# Count: 3
# Working on postcode 0050 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0050
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stenersgata&kommune=301
# Working on: Stenersgata
# Stenersgata 59.91311111111111 10.752633333333334
#
#
# Count: 4
# Working on postcode 0139 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0139
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Blåskjellveien&kommune=301
# Working on: Blåskjellveien
# Blåskjellveien 59.870850000000004 10.771999999999998
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fiskekroken&kommune=301
# Working on: Fiskekroken
# Fiskekroken 59.87151269841268 10.772650793650794
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fjordveien&kommune=301
# Working on: Fjordveien
# Fjordveien 59.86909629629628 10.772303703703702
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hummerkloa&kommune=301
# Working on: Hummerkloa
# Hummerkloa 59.868579999999994 10.77136
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Måkeveien&kommune=301
# Working on: Måkeveien
# Måkeveien 59.86871923076922 10.771563461538465
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pans vei&kommune=301
# Working on: Pans vei
# Pans vei 59.86917857142858 10.773832142857142
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Vargveien&kommune=301
# Working on: Vargveien
# Vargveien 59.870325 10.773368750000001
#
#
# Count: 5
# Working on postcode 0150 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0150
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akershusstranda&kommune=301
# Working on: Akershusstranda
# Akershusstranda 59.90571249999999 10.738475000000003
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Anne-Cath. Vestlys plass&kommune=301
# Working on: Anne-Cath. Vestlys plass
# Anne-Cath. Vestlys plass 59.9087 10.7521
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bleikøya&kommune=301
# Working on: Bleikøya
# Bleikøya 59.88879300000001 10.738625000000003
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dronning Eufemias gate&kommune=301
# Working on: Dronning Eufemias gate
# Dronning Eufemias gate 59.90765666666665 10.758471666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Glacisgata&kommune=301
# Working on: Glacisgata
# Glacisgata 59.9061 10.7429
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Henny Mürers gang&kommune=301
# Working on: Henny Mürers gang
# Henny Mürers gang 59.90825555555554 10.75438888888889
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kirsten Flagstads plass&kommune=301
# Working on: Kirsten Flagstads plass
# Kirsten Flagstads plass 59.9078 10.7521
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Langkaia&kommune=301
# Working on: Langkaia
# Langkaia 59.9076 10.7469
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lindøya&kommune=301
# Working on: Lindøya
# Lindøya 59.88900091463418 10.71102469512195
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nakholmen&kommune=301
# Working on: Nakholmen
# Nakholmen 59.88964973262032 10.6946614973262
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nylandsveien&kommune=301
# Working on: Nylandsveien
# Nylandsveien 59.9073 10.754550000000002
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Operagata&kommune=301
# Working on: Operagata
# Operagata 59.906899999999986 10.757153424657531
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Robert Levins gate&kommune=301
# Working on: Robert Levins gate
# Robert Levins gate 59.908433333333335 10.7534
#
#
# Count: 6
# Working on postcode 0151 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0151
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akershusstranda&kommune=301
# Working on: Akershusstranda
# Akershusstranda 59.90571249999999 10.738475000000003
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bankplassen&kommune=301
# Working on: Bankplassen
# Bankplassen 59.90884 10.741500000000002
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dronningens gate&kommune=301
# Working on: Dronningens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grev Wedels plass&kommune=301
# Working on: Grev Wedels plass
# Grev Wedels plass 59.90765 10.742675
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Myntgata&kommune=301
# Working on: Myntgata
# Myntgata 59.90866666666667 10.738033333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Revierstredet&kommune=301
# Working on: Revierstredet
# Revierstredet 59.908325 10.742750000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusgata&kommune=301
# Working on: Rådhusgata
# Rådhusgata 59.909575757575766 10.742184848484852

# %%
print(failedStreet)
# Out:
# ['Dronningens gate']

# %% [markdown]
# #### NOTE: FOLLOWING CODE TAKES ~45 mins to RUN

# %%
#LONG CODE # RUN ONLY IF ABSOLUTELY REQUIRED

#Extract tags that are in use
tagsinUse = soup.find_all('tr', class_ = 'ibruk')

count = 0 #Initiate counter
midStreetDict = dict()
midStreetLoc = list()

for i in tagsinUse:      
    if re.search('Gate-/veg-adresse', str(i.contents)): #i.e. print only if postbox belongs to gate/veg-adresse
        
        #For intial testing
        count = count +1
        #if count > 4:break
        print('\nCount: {}'.format(count))
        print('Working on postcode {}...'.format(i.th.a.text))
        posturl = i.th.a.get('href', None )#Postcode link
        postCheck(posturl)#Custom function defined above
        
        #Parse Postcode link and open it
        html2 = urllib.request.urlopen(posturl, context=cntxt)#Open, similar to filehandle
        #print('HTML2 is {}'.format(html2))
        soup2 = BeautifulSoup(html2, 'html.parser')#Parse
        #print(soup2)
        
        #Establish canonical link that will combine with street address URL to form new URL
        canonical = 'https://www.erikbolstad.no/postnummer-koordinatar/'
        
        #Extract tag in the new link
        tagsinUse2 = soup2.find_all('table', style="margin-top: 4rem;")
        for j in tagsinUse2:
            #print('\n<<<<Printing all tags selected from soup2...>>>>')
            #print(j)
            td = j.find_all('td', itemtype="https://schema.org/StreetAddress")#Find the street addresses
            #print('<<<<Printing td tags...>>>>')
            #print(td,'\n')
            #print(j.td.a.text)#Gives only 1 street address#Early version of script
            for tag in td:
                streetUrl = canonical+tag.a.get('href',None)
                streetName = tag.a.text
                print(streetUrl)
                #print('Working on:', tag.a.text,'\n')
                print('Working on:', streetName)
                
                #Parse street url link and open it
                try:
                    #html3 = urllib.request.urlopen(streetUrl, context=cntxt)#Open, similar to filehandle
                    html3 = requests.get(streetUrl).text
                    #print('HTML3 is {}'.format(html3))
                    soup3 = BeautifulSoup(html3, 'html.parser')#Parse
                
                    #Extract all anchor tags since within them one finds the street address + geocoordinates
                    streets = soup3.find_all('a')
    
                    streetList = []
                    latlonList = []
                    #latlonTup = tuple()
                    for datas in streets:
                        text = datas.text
                        #print(text) 
                        #Only get the text that is street name or lat, long
                        if re.search(streetName+'\s[0-9]+', text):# or re.findall('[0-9]+,', text):
                            #print(text)
                            streetList.append(text)
                     
                        elif re.search('[0-9]+,', text):
                            coordinates = text.split(',')
                            #print(tuple(coordinates)) #Make into latlon coordinates tuple so that it can be appended to list
                            latlonList.append(tuple(coordinates))
                        
                        #print(streetList)
                        #print(latlonList)
                    combined = dict(zip(streetList, latlonList))
                
                    #Establish mid-points of streets
                    lat2 = []
                    long2 = []
                    for l in latlonList :
                        lat2.append(float(l[0]))
                        long2.append(float(l[1]))

                    midStreetLat = sum(lat2)/len(lat2)
                    midStreetLon = sum(long2)/len(long2)
                #midStreetStr= str(midStreetLat) +','+ str(midStreetLon)
                #midStreetCoord = midStreetStr.split(',')
                #midStreetLoc.append((midStreetLat,midStreetLon))
                    midStreetLoc.append(midStreetLat), midStreetLoc.append(midStreetLon)
                    print(streetName,midStreetLat, midStreetLon,'\n')
                    midStreetDict[streetName] = midStreetLoc
                    midStreetLoc = []
                except:
                    print('Can\'t open URL, possible UnicodeEncode error. Skipping...\n')
# Out:
# Count: 1
# Working on postcode 0018 OSLO...
# Exceptional post found, skipping...
#
# Count: 2
# Working on postcode 0045 OSLO...
# Exceptional post found, skipping...
#
# Count: 3
# Working on postcode 0050 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0050
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stenersgata&kommune=301
# Working on: Stenersgata
# Stenersgata 59.91311111111111 10.752633333333334
#
#
# Count: 4
# Working on postcode 0139 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0139
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Blåskjellveien&kommune=301
# Working on: Blåskjellveien
# Blåskjellveien 59.870850000000004 10.771999999999998
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fiskekroken&kommune=301
# Working on: Fiskekroken
# Fiskekroken 59.87151269841268 10.772650793650794
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fjordveien&kommune=301
# Working on: Fjordveien
# Fjordveien 59.86909629629628 10.772303703703702
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hummerkloa&kommune=301
# Working on: Hummerkloa
# Hummerkloa 59.868579999999994 10.77136
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Måkeveien&kommune=301
# Working on: Måkeveien
# Måkeveien 59.86871923076922 10.771563461538465
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pans vei&kommune=301
# Working on: Pans vei
# Pans vei 59.86917857142858 10.773832142857142
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Vargveien&kommune=301
# Working on: Vargveien
# Vargveien 59.870325 10.773368750000001
#
#
# Count: 5
# Working on postcode 0150 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0150
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akershusstranda&kommune=301
# Working on: Akershusstranda
# Akershusstranda 59.90571249999999 10.738475000000003
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Anne-Cath. Vestlys plass&kommune=301
# Working on: Anne-Cath. Vestlys plass
# Anne-Cath. Vestlys plass 59.9087 10.7521
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bleikøya&kommune=301
# Working on: Bleikøya
# Bleikøya 59.88879300000001 10.738625000000003
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dronning Eufemias gate&kommune=301
# Working on: Dronning Eufemias gate
# Dronning Eufemias gate 59.90765666666665 10.758471666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Glacisgata&kommune=301
# Working on: Glacisgata
# Glacisgata 59.9061 10.7429
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Henny Mürers gang&kommune=301
# Working on: Henny Mürers gang
# Henny Mürers gang 59.90825555555554 10.75438888888889
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kirsten Flagstads plass&kommune=301
# Working on: Kirsten Flagstads plass
# Kirsten Flagstads plass 59.9078 10.7521
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Langkaia&kommune=301
# Working on: Langkaia
# Langkaia 59.9076 10.7469
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lindøya&kommune=301
# Working on: Lindøya
# Lindøya 59.88900091463418 10.71102469512195
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nakholmen&kommune=301
# Working on: Nakholmen
# Nakholmen 59.88964973262032 10.6946614973262
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nylandsveien&kommune=301
# Working on: Nylandsveien
# Nylandsveien 59.9073 10.754550000000002
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Operagata&kommune=301
# Working on: Operagata
# Operagata 59.906899999999986 10.757153424657531
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Robert Levins gate&kommune=301
# Working on: Robert Levins gate
# Robert Levins gate 59.908433333333335 10.7534
#
#
# Count: 6
# Working on postcode 0151 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0151
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akershusstranda&kommune=301
# Working on: Akershusstranda
# Akershusstranda 59.90571249999999 10.738475000000003
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bankplassen&kommune=301
# Working on: Bankplassen
# Bankplassen 59.90884 10.741500000000002
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dronningens gate&kommune=301
# Working on: Dronningens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grev Wedels plass&kommune=301
# Working on: Grev Wedels plass
# Grev Wedels plass 59.90765 10.742675
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Myntgata&kommune=301
# Working on: Myntgata
# Myntgata 59.90866666666667 10.738033333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Revierstredet&kommune=301
# Working on: Revierstredet
# Revierstredet 59.908325 10.742750000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusgata&kommune=301
# Working on: Rådhusgata
# Rådhusgata 59.909575757575766 10.742184848484852
#
#
# Count: 7
# Working on postcode 0152 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0152
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dronningens gate&kommune=301
# Working on: Dronningens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fred. Olsens gate&kommune=301
# Working on: Fred. Olsens gate
# Fred. Olsens gate 59.9096 10.747857142857143
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Prinsens gate&kommune=301
# Working on: Prinsens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Skippergata&kommune=301
# Working on: Skippergata
# Skippergata 59.91033877551018 10.747330612244895
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Strandgata&kommune=301
# Working on: Strandgata
# Strandgata 59.909949999999995 10.7492
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tollbugata&kommune=301
# Working on: Tollbugata
# Tollbugata 59.910413333333345 10.744176666666668
#
#
# Count: 8
# Working on postcode 0153 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0153
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kirkegata&kommune=301
# Working on: Kirkegata
# Kirkegata 59.9102935483871 10.743754838709675
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kongens gate&kommune=301
# Working on: Kongens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nedre Slottsgate&kommune=301
# Working on: Nedre Slottsgate
# Nedre Slottsgate 59.911486956521735 10.741895652173913
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Revierstredet&kommune=301
# Working on: Revierstredet
# Revierstredet 59.908325 10.742750000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusgata&kommune=301
# Working on: Rådhusgata
# Rådhusgata 59.909575757575766 10.742184848484852
#
#
# Count: 9
# Working on postcode 0154 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0154
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dronningens gate&kommune=301
# Working on: Dronningens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Europarådets plass&kommune=301
# Working on: Europarådets plass
# Europarådets plass 59.912 10.7493
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Jernbanetorget&kommune=301
# Working on: Jernbanetorget
# Jernbanetorget 59.9113 10.750425
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Karl Johans gate&kommune=301
# Working on: Karl Johans gate
# Karl Johans gate 59.91279375000001 10.74283333333333
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Prinsens gate&kommune=301
# Working on: Prinsens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Skippergata&kommune=301
# Working on: Skippergata
# Skippergata 59.91033877551018 10.747330612244895
#
#
# Count: 10
# Working on postcode 0155 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0155
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Biskop Gunnerus’ gate&kommune=301
# Working on: Biskop Gunnerus’ gate
# Biskop Gunnerus’ gate 59.91205 10.752583333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kirkeristen&kommune=301
# Working on: Kirkeristen
# Kirkeristen 59.913 10.74745
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nygata&kommune=301
# Working on: Nygata
# Nygata 59.91315 10.75075
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Storgata&kommune=301
# Working on: Storgata
# Storgata 59.91532580645159 10.754066666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stortorvet&kommune=301
# Working on: Stortorvet
# Stortorvet 59.912733333333335 10.745588888888891
#
#
# Count: 11
# Working on postcode 0157 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0157
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Christiania torv&kommune=301
# Working on: Christiania torv
# Christiania torv 59.91 10.74
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nedre Slottsgate&kommune=301
# Working on: Nedre Slottsgate
# Nedre Slottsgate 59.911486956521735 10.741895652173913
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Prinsens gate&kommune=301
# Working on: Prinsens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tollbugata&kommune=301
# Working on: Tollbugata
# Tollbugata 59.910413333333345 10.744176666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Øvre Slottsgate&kommune=301
# Working on: Øvre Slottsgate
# Øvre Slottsgate 59.912312 10.741635999999998
#
#
# Count: 12
# Working on postcode 0158 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0158
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akersgata&kommune=301
# Working on: Akersgata
# Akersgata 59.914448936170224 10.74251063829787
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nedre Vollgate&kommune=301
# Working on: Nedre Vollgate
# Nedre Vollgate 59.91147500000002 10.738325000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Prinsens gate&kommune=301
# Working on: Prinsens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusgata&kommune=301
# Working on: Rådhusgata
# Rådhusgata 59.909575757575766 10.742184848484852
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stortingsgata&kommune=301
# Working on: Stortingsgata
# Stortingsgata 59.913614285714296 10.735721428571427
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tollbugata&kommune=301
# Working on: Tollbugata
# Tollbugata 59.910413333333345 10.744176666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Øvre Vollgate&kommune=301
# Working on: Øvre Vollgate
# Øvre Vollgate 59.91142222222223 10.737111111111112
#
#
# Count: 13
# Working on postcode 0159 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0159
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Arbeidergata&kommune=301
# Working on: Arbeidergata
# Arbeidergata 59.91426666666666 10.740699999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grensen&kommune=301
# Working on: Grensen
# Grensen 59.91390000000001 10.743077777777776
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Karl Johans gate&kommune=301
# Working on: Karl Johans gate
# Karl Johans gate 59.91279375000001 10.74283333333333
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lille Grensen&kommune=301
# Working on: Lille Grensen
# Lille Grensen 59.913775 10.74135
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rosenkrantz’ gate&kommune=301
# Working on: Rosenkrantz’ gate
# Rosenkrantz’ gate 59.91342777777777 10.738272222222223
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Øvre Slottsgate&kommune=301
# Working on: Øvre Slottsgate
# Øvre Slottsgate 59.912312 10.741635999999998
#
#
# Count: 14
# Working on postcode 0160 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0160
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fridtjof Nansens plass&kommune=301
# Working on: Fridtjof Nansens plass
# Fridtjof Nansens plass 59.912839999999996 10.734309999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hieronymus Heyerdahls gate&kommune=301
# Working on: Hieronymus Heyerdahls gate
# Hieronymus Heyerdahls gate 59.9118 10.7345
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kjeld Stubs gate&kommune=301
# Working on: Kjeld Stubs gate
# Kjeld Stubs gate 59.9129 10.7356
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kronprinsesse Märthas plass&kommune=301
# Working on: Kronprinsesse Märthas plass
# Kronprinsesse Märthas plass 59.9128 10.733
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rolf Strangers plass&kommune=301
# Working on: Rolf Strangers plass
# Rolf Strangers plass 59.9102 10.734166666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rosenkrantz’ gate&kommune=301
# Working on: Rosenkrantz’ gate
# Rosenkrantz’ gate 59.91342777777777 10.738272222222223
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusbrygge 1&kommune=301
# Working on: Rådhusbrygge 1
# Rådhusbrygge 1 59.9099 10.7337
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusbrygge 2&kommune=301
# Working on: Rådhusbrygge 2
# Rådhusbrygge 2 59.91 10.7328
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusbrygge 3&kommune=301
# Working on: Rådhusbrygge 3
# Rådhusbrygge 3 59.9103 10.7314
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådhusbrygge 4&kommune=301
# Working on: Rådhusbrygge 4
# Rådhusbrygge 4 59.9104 10.7304
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tordenskiolds gate&kommune=301
# Working on: Tordenskiolds gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
#
# Count: 15
# Working on postcode 0161 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0161
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Haakon VII’s gate&kommune=301
# Working on: Haakon VII’s gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Johanne Dybwads plass&kommune=301
# Working on: Johanne Dybwads plass
# Johanne Dybwads plass 59.9146 10.7336
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Klingenberggata&kommune=301
# Working on: Klingenberggata
# Klingenberggata 59.913675 10.73275
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Munkedamsveien&kommune=301
# Working on: Munkedamsveien
# Munkedamsveien 59.91177260273975 10.719087671232874
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Olav Vs gate&kommune=301
# Working on: Olav Vs gate
# Olav Vs gate 59.91328333333333 10.732433333333333
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Roald Amundsens gate&kommune=301
# Working on: Roald Amundsens gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stortingsgata&kommune=301
# Working on: Stortingsgata
# Stortingsgata 59.913614285714296 10.735721428571427
#
#
# Count: 16
# Working on postcode 0162 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0162
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Karl Johans gate&kommune=301
# Working on: Karl Johans gate
# Karl Johans gate 59.91279375000001 10.74283333333333
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Universitetsgata&kommune=301
# Working on: Universitetsgata
# Universitetsgata 59.916219999999996 10.738180000000002
#
#
# Count: 17
# Working on postcode 0164 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0164
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=C. J. Hambros plass&kommune=301
# Working on: C. J. Hambros plass
# C. J. Hambros plass 59.91578 10.7411
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Frederiks gate&kommune=301
# Working on: Frederiks gate
# Frederiks gate 59.9169 10.735050000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kristian Augusts gate&kommune=301
# Working on: Kristian Augusts gate
# Kristian Augusts gate 59.91653333333333 10.738455555555557
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kristian IV’s gate&kommune=301
# Working on: Kristian IV’s gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pilestredet&kommune=301
# Working on: Pilestredet
# Pilestredet 59.92450281690138 10.733014084507042
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sehesteds gate&kommune=301
# Working on: Sehesteds gate
# Sehesteds gate 59.915749999999996 10.7391
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Universitetsgata&kommune=301
# Working on: Universitetsgata
# Universitetsgata 59.916219999999996 10.738180000000002
#
#
# Count: 18
# Working on postcode 0165 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0165
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bernhard Getz’ gate&kommune=301
# Working on: Bernhard Getz’ gate
# Bernhard Getz’ gate 59.917249999999996 10.74235
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bidenkaps gate&kommune=301
# Working on: Bidenkaps gate
# Bidenkaps gate 59.919271428571435 10.741042857142856
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Frimanns gate&kommune=301
# Working on: Frimanns gate
# Frimanns gate 59.920463636363635 10.741118181818182
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Keysers gate&kommune=301
# Working on: Keysers gate
# Keysers gate 59.91682307692307 10.742769230769234
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kommandør T. I. Øgrims plass&kommune=301
# Working on: Kommandør T. I. Øgrims plass
# Kommandør T. I. Øgrims plass 59.917500000000004 10.742999999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Langes gate&kommune=301
# Working on: Langes gate
# Langes gate 59.91889285714286 10.740028571428569
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Munchs gate&kommune=301
# Working on: Munchs gate
# Munchs gate 59.917014285714295 10.741499999999998
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nordahl Bruns gate&kommune=301
# Working on: Nordahl Bruns gate
# Nordahl Bruns gate 59.91885483870968 10.740703225806449
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Peder Claussøns gate&kommune=301
# Working on: Peder Claussøns gate
# Peder Claussøns gate 59.917730000000006 10.74169
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=St. Olavs gate&kommune=301
# Working on: St. Olavs gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=St. Olavs plass&kommune=301
# Working on: St. Olavs plass
# St. Olavs plass 59.91805 10.740099999999998
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Ullevålsveien&kommune=301
# Working on: Ullevålsveien
# Ullevålsveien 59.929901369863 10.735761643835618
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Wessels gate&kommune=301
# Working on: Wessels gate
# Wessels gate 59.91975555555554 10.74171851851852
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Zetlitz’ gate&kommune=301
# Working on: Zetlitz’ gate
# Zetlitz’ gate 59.9201923076923 10.741684615384619
#
#
# Count: 19
# Working on postcode 0166 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0166
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Edvard Storms gate&kommune=301
# Working on: Edvard Storms gate
# Edvard Storms gate 59.9192 10.73515
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Holbergs gate&kommune=301
# Working on: Holbergs gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Holbergs plass&kommune=301
# Working on: Holbergs plass
# Holbergs plass 59.91943333333333 10.734166666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Linstows gate&kommune=301
# Working on: Linstows gate
# Linstows gate 59.91955555555556 10.731922222222224
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pilestredet&kommune=301
# Working on: Pilestredet
# Pilestredet 59.92450281690138 10.733014084507042
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=St. Olavs gate&kommune=301
# Working on: St. Olavs gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Staffeldts gate&kommune=301
# Working on: Staffeldts gate
# Staffeldts gate 59.918974999999996 10.732624999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sven Bruns gate&kommune=301
# Working on: Sven Bruns gate
# Sven Bruns gate 59.91941428571429 10.733142857142855
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tullins gate&kommune=301
# Working on: Tullins gate
# Tullins gate 59.918483333333334 10.734816666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Welhavens gate&kommune=301
# Working on: Welhavens gate
# Welhavens gate 59.92038372093021 10.732418604651166
#
#
# Count: 20
# Working on postcode 0167 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0167
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dalsbergstien&kommune=301
# Working on: Dalsbergstien
# Dalsbergstien 59.92291142857144 10.73652857142857
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hegdehaugsveien&kommune=301
# Working on: Hegdehaugsveien
# Hegdehaugsveien 59.920855555555555 10.729809259259257
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pilestredet&kommune=301
# Working on: Pilestredet
# Pilestredet 59.92450281690138 10.733014084507042
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Wergelandsveien&kommune=301
# Working on: Wergelandsveien
# Wergelandsveien 59.919113333333335 10.730633333333333
#
#
# Count: 21
# Working on postcode 0168 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0168
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bislettgata&kommune=301
# Working on: Bislettgata
# Bislettgata 59.924375 10.73275
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bolteløkka allé&kommune=301
# Working on: Bolteløkka allé
# Bolteløkka allé 59.92848 10.736733333333335
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Eugenies gate&kommune=301
# Working on: Eugenies gate
# Eugenies gate 59.92768181818181 10.736109090909094
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Laura Gundersens gate&kommune=301
# Working on: Laura Gundersens gate
# Laura Gundersens gate 59.92638333333333 10.732683333333332
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Louises gate&kommune=301
# Working on: Louises gate
# Louises gate 59.92658333333335 10.735744444444443
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Snorres gate&kommune=301
# Working on: Snorres gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sofies gate&kommune=301
# Working on: Sofies gate
# Sofies gate 59.925974683544304 10.735031645569618
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Thereses gate&kommune=301
# Working on: Thereses gate
# Thereses gate 59.92893529411763 10.732704901960783
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Wilhelms gate&kommune=301
# Working on: Wilhelms gate
# Wilhelms gate 59.927046666666676 10.7339
#
#
# Count: 22
# Working on postcode 0169 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0169
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Benneches gate&kommune=301
# Working on: Benneches gate
# Benneches gate 59.92483333333334 10.736366666666669
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Colletts gate&kommune=301
# Working on: Colletts gate
# Colletts gate 59.929080769230765 10.74285192307692
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Frydenlundgata&kommune=301
# Working on: Frydenlundgata
# Frydenlundgata 59.92404062499998 10.737246875000002
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Henrichsens gate&kommune=301
# Working on: Henrichsens gate
# Henrichsens gate 59.925266666666666 10.737366666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Krafts gate&kommune=301
# Working on: Krafts gate
# Krafts gate 59.92398333333333 10.736416666666669
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Louises gate&kommune=301
# Working on: Louises gate
# Louises gate 59.92658333333335 10.735744444444443
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Mikkel Doblougs gate&kommune=301
# Working on: Mikkel Doblougs gate
# Mikkel Doblougs gate 59.925900000000006 10.735733333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sofies plass&kommune=301
# Working on: Sofies plass
# Sofies plass 59.923766666666666 10.735544444444443
#
#
# Count: 23
# Working on postcode 0170 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0170
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bislettgata&kommune=301
# Working on: Bislettgata
# Bislettgata 59.924375 10.73275
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dalsbergstien&kommune=301
# Working on: Dalsbergstien
# Dalsbergstien 59.92291142857144 10.73652857142857
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dovregata&kommune=301
# Working on: Dovregata
# Dovregata 59.92182499999999 10.737516666666666
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Falbes gate&kommune=301
# Working on: Falbes gate
# Falbes gate 59.92220833333334 10.734941666666666
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Glückstads gate&kommune=301
# Working on: Glückstads gate
# Glückstads gate 59.92236666666667 10.738083333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hallings gate&kommune=301
# Working on: Hallings gate
# Hallings gate 59.922444444444444 10.738911111111111
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Krumgata&kommune=301
# Working on: Krumgata
# Krumgata 59.922374999999995 10.73683125
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lille Bislett&kommune=301
# Working on: Lille Bislett
# Lille Bislett 59.923614285714294 10.732914285714287
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Schwensens gate&kommune=301
# Working on: Schwensens gate
# Schwensens gate 59.92410357142858 10.738453571428568
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sofies gate&kommune=301
# Working on: Sofies gate
# Sofies gate 59.925974683544304 10.735031645569618
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stensberggata&kommune=301
# Working on: Stensberggata
# Stensberggata 59.92163333333333 10.738114285714286
#
#
# Count: 24
# Working on postcode 0171 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0171
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brandts gate&kommune=301
# Working on: Brandts gate
# Brandts gate 59.926550000000006 10.74415
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Elias Blix’ gate&kommune=301
# Working on: Elias Blix’ gate
# Elias Blix’ gate 59.9281 10.7462
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Geitmyrsveien&kommune=301
# Working on: Geitmyrsveien
# Geitmyrsveien 59.93007439024388 10.743064634146343
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Herman Foss’ gate&kommune=301
# Working on: Herman Foss’ gate
# Herman Foss’ gate 59.9281564102564 10.74548205128205
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Ilagata&kommune=301
# Working on: Ilagata
# Ilagata 59.929 10.7463
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Ullevålsveien&kommune=301
# Working on: Ullevålsveien
# Ullevålsveien 59.929901369863 10.735761643835618
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Waldemar Thranes gate&kommune=301
# Working on: Waldemar Thranes gate
# Waldemar Thranes gate 59.92601140350876 10.745293859649122
#
#
# Count: 25
# Working on postcode 0172 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0172
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akersbakken&kommune=301
# Working on: Akersbakken
# Akersbakken 59.92406756756755 10.745916216216216
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akersveien&kommune=301
# Working on: Akersveien
# Akersveien 59.920152777777766 10.746030555555556
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bergstien&kommune=301
# Working on: Bergstien
# Bergstien 59.92439047619049 10.743533333333332
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bjerregaards gate&kommune=301
# Working on: Bjerregaards gate
# Bjerregaards gate 59.92498440366973 10.744984403669726
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fredrikke Qvams gate&kommune=301
# Working on: Fredrikke Qvams gate
# Fredrikke Qvams gate 59.9241551724138 10.745496551724138
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hans Ross’ gate&kommune=301
# Working on: Hans Ross’ gate
# Hans Ross’ gate 59.924625 10.745225
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Telthusbakken&kommune=301
# Working on: Telthusbakken
# Telthusbakken 59.923476190476194 10.74852857142857
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Ungers gate&kommune=301
# Working on: Ungers gate
# Ungers gate 59.9253 10.7451
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Westye Egebergs gate&kommune=301
# Working on: Westye Egebergs gate
# Westye Egebergs gate 59.921665 10.74814
#
#
# Count: 26
# Working on postcode 0173 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0173
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Evald Ryghs gate&kommune=301
# Working on: Evald Ryghs gate
# Evald Ryghs gate 59.92932 10.74625
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fougstads gate&kommune=301
# Working on: Fougstads gate
# Fougstads gate 59.92799534883723 10.746879069767441
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Waldemar Thranes gate&kommune=301
# Working on: Waldemar Thranes gate
# Waldemar Thranes gate 59.92601140350876 10.745293859649122
#
#
# Count: 27
# Working on postcode 0174 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0174
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bjerregaards gate&kommune=301
# Working on: Bjerregaards gate
# Bjerregaards gate 59.92498440366973 10.744984403669726
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Casparis gate&kommune=301
# Working on: Casparis gate
# Casparis gate 59.925812500000006 10.748775000000002
#
#
# Count: 28
# Working on postcode 0175 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0175
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Darres gate&kommune=301
# Working on: Darres gate
# Darres gate 59.92778750000001 10.752825
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hauchs gate&kommune=301
# Working on: Hauchs gate
# Hauchs gate 59.9264666666667 10.751820000000004
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Maridalsveien&kommune=301
# Working on: Maridalsveien
# Maridalsveien 59.94757031578944 10.759898315789474
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Uelands gate&kommune=301
# Working on: Uelands gate
# Uelands gate 59.93198235294118 10.749760000000002
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Waldemar Thranes gate&kommune=301
# Working on: Waldemar Thranes gate
# Waldemar Thranes gate 59.92601140350876 10.745293859649122
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Waldemars hage&kommune=301
# Working on: Waldemars hage
# Waldemars hage 59.92704999999999 10.75255
#
#
# Count: 29
# Working on postcode 0176 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0176
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pilestredet park&kommune=301
# Working on: Pilestredet park
# Pilestredet park 59.920476 10.738706000000002
#
#
# Count: 30
# Working on postcode 0177 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0177
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akersveien&kommune=301
# Working on: Akersveien
# Akersveien 59.920152777777766 10.746030555555556
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Damstredet&kommune=301
# Working on: Damstredet
# Damstredet 59.920028571428574 10.747661904761904
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dops gate&kommune=301
# Working on: Dops gate
# Dops gate 59.9196 10.747100000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Fredensborgveien&kommune=301
# Working on: Fredensborgveien
# Fredensborgveien 59.91893222222222 10.748018888888886
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rosings gate&kommune=301
# Working on: Rosings gate
# Rosings gate 59.9196 10.74515
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Schandorffs gate&kommune=301
# Working on: Schandorffs gate
# Schandorffs gate 59.9174 10.7463
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Thor Olsens gate&kommune=301
# Working on: Thor Olsens gate
# Thor Olsens gate 59.918104000000014 10.74586
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Westye Egebergs gate&kommune=301
# Working on: Westye Egebergs gate
# Westye Egebergs gate 59.921665 10.74814
#
#
# Count: 31
# Working on postcode 0178 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0178
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Deichmans gate&kommune=301
# Working on: Deichmans gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Iduns gate&kommune=301
# Working on: Iduns gate
# Iduns gate 59.92018888888887 10.750394444444444
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Maridalsveien&kommune=301
# Working on: Maridalsveien
# Maridalsveien 59.94757031578944 10.759898315789474
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rosteds gate&kommune=301
# Working on: Rosteds gate
# Rosteds gate 59.91940416666665 10.7499625
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Vulkan&kommune=301
# Working on: Vulkan
# Vulkan 59.92234 10.751876666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Wilses gate&kommune=301
# Working on: Wilses gate
# Wilses gate 59.91817272727272 10.749154545454545
#
#
# Count: 32
# Working on postcode 0179 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0179
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Arne Garborgs plass&kommune=301
# Working on: Arne Garborgs plass
# Arne Garborgs plass 59.9163 10.74695
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Einar Gerhardsens plass&kommune=301
# Working on: Einar Gerhardsens plass
# Einar Gerhardsens plass 59.91525 10.7469
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grubbegata&kommune=301
# Working on: Grubbegata
# Grubbegata 59.914625 10.745800000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hammersborg torg&kommune=301
# Working on: Hammersborg torg
# Hammersborg torg 59.91697142857142 10.747657142857141
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hammersborggata&kommune=301
# Working on: Hammersborggata
# Hammersborggata 59.915608695652175 10.75017391304348
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Linaaes gate&kommune=301
# Working on: Linaaes gate
# Can't open URL, possible UnicodeEncode error. Skipping...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Møllergata&kommune=301
# Working on: Møllergata
# Møllergata 59.916619999999995 10.749266
#
#
# Count: 33
# Working on postcode 0180 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0180
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Akersgata&kommune=301
# Working on: Akersgata
# Akersgata 59.914448936170224 10.74251063829787
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Apotekergata&kommune=301
# Working on: Apotekergata
# Apotekergata 59.915175000000005 10.742300000000002
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grensen&kommune=301
# Working on: Grensen
# Grensen 59.91390000000001 10.743077777777776
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Høyesteretts plass&kommune=301
# Working on: Høyesteretts plass
# Høyesteretts plass 59.9146 10.7445
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Munchs gate&kommune=301
# Working on: Munchs gate
# Munchs gate 59.917014285714295 10.741499999999998
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pilestredet&kommune=301
# Working on: Pilestredet
# Pilestredet 59.92450281690138 10.733014084507042
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Professor Aschehougs plass&kommune=301
# Working on: Professor Aschehougs plass
# Professor Aschehougs plass 59.9149 10.7406
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Teatergata&kommune=301
# Working on: Teatergata
# Teatergata 59.91610000000001 10.7433875
#
#
# Count: 34
# Working on postcode 0181 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0181
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Arbeidersamfunnets plass&kommune=301
# Working on: Arbeidersamfunnets plass
# Arbeidersamfunnets plass 59.9155 10.7518
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Calmeyers gate&kommune=301
# Working on: Calmeyers gate
# Calmeyers gate 59.91605416666669 10.754166666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hammersborggata&kommune=301
# Working on: Hammersborggata
# Hammersborggata 59.915608695652175 10.75017391304348
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pløens gate&kommune=301
# Working on: Pløens gate
# Pløens gate 59.91389999999999 10.749325
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Torggata&kommune=301
# Working on: Torggata
# Torggata 59.91594222222222 10.751355555555556
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Youngs gate&kommune=301
# Working on: Youngs gate
# Youngs gate 59.91497777777777 10.750277777777779
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Youngstorget&kommune=301
# Working on: Youngstorget
# Youngstorget 59.91458333333333 10.749083333333333
#
#
# Count: 35
# Working on postcode 0182 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0182
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brenneriveien&kommune=301
# Working on: Brenneriveien
# Brenneriveien 59.92001666666667 10.752366666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hausmanns gate&kommune=301
# Working on: Hausmanns gate
# Hausmanns gate 59.91746097560975 10.754663414634146
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Mariboes gate&kommune=301
# Working on: Mariboes gate
# Mariboes gate 59.91666470588235 10.750894117647059
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Møllerveien&kommune=301
# Working on: Møllerveien
# Møllerveien 59.921350000000004 10.751999999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Storgata&kommune=301
# Working on: Storgata
# Storgata 59.91532580645159 10.754066666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Torggata&kommune=301
# Working on: Torggata
# Torggata 59.91594222222222 10.751355555555556
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Vestre Elvebakke&kommune=301
# Working on: Vestre Elvebakke
# Vestre Elvebakke 59.91913333333333 10.752966666666666
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Vulkan&kommune=301
# Working on: Vulkan
# Vulkan 59.92234 10.751876666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Østre Elvebakke&kommune=301
# Working on: Østre Elvebakke
# Østre Elvebakke 59.918925 10.754324999999998
#
#
# Count: 36
# Working on postcode 0183 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0183
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Badstugata&kommune=301
# Working on: Badstugata
# Badstugata 59.916160000000005 10.75076
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bernt Ankers gate&kommune=301
# Working on: Bernt Ankers gate
# Bernt Ankers gate 59.916063636363646 10.751927272727272
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Calmeyers gate&kommune=301
# Working on: Calmeyers gate
# Calmeyers gate 59.91605416666669 10.754166666666668
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Ebbells gate&kommune=301
# Working on: Ebbells gate
# Ebbells gate 59.91548235294118 10.754041176470588
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Jess Carlsens gate&kommune=301
# Working on: Jess Carlsens gate
# Jess Carlsens gate 59.91847142857142 10.751585714285714
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Mariboes gate&kommune=301
# Working on: Mariboes gate
# Mariboes gate 59.91666470588235 10.750894117647059
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Osterhaus’ gate&kommune=301
# Working on: Osterhaus’ gate
# Osterhaus’ gate 59.91660877192984 10.75359298245614
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Torggata&kommune=301
# Working on: Torggata
# Torggata 59.91594222222222 10.751355555555556
#
#
# Count: 37
# Working on postcode 0184 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0184
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lilletorget&kommune=301
# Working on: Lilletorget
# Lilletorget 59.9135 10.7559
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lybekkergata&kommune=301
# Working on: Lybekkergata
# Lybekkergata 59.91356666666667 10.752766666666666
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nygata&kommune=301
# Working on: Nygata
# Nygata 59.91315 10.75075
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stenersgata&kommune=301
# Working on: Stenersgata
# Stenersgata 59.91311111111111 10.752633333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Storgata&kommune=301
# Working on: Storgata
# Storgata 59.91532580645159 10.754066666666668
#
#
# Count: 38
# Working on postcode 0185 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0185
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Biskop Gunnerus’ gate&kommune=301
# Working on: Biskop Gunnerus’ gate
# Biskop Gunnerus’ gate 59.91205 10.752583333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Schweigaards gate&kommune=301
# Working on: Schweigaards gate
# Schweigaards gate 59.90820808823531 10.77109852941176
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sonja Henies plass&kommune=301
# Working on: Sonja Henies plass
# Sonja Henies plass 59.9127 10.7555
#
#
# Count: 39
# Working on postcode 0186 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0186
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brugata&kommune=301
# Working on: Brugata
# Brugata 59.91400526315789 10.755773684210526
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Christian Krohgs gate&kommune=301
# Working on: Christian Krohgs gate
# Christian Krohgs gate 59.9159696969697 10.759327272727274
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hausmanns gate&kommune=301
# Working on: Hausmanns gate
# Hausmanns gate 59.91746097560975 10.754663414634146
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nedre Vaskegang&kommune=301
# Working on: Nedre Vaskegang
# Nedre Vaskegang 59.917109090909086 10.760863636363636
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Slåmotgangen&kommune=301
# Working on: Slåmotgangen
# Slåmotgangen 59.91676666666667 10.761166666666668
#
#
# Count: 40
# Working on postcode 0187 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0187
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Breigata&kommune=301
# Working on: Breigata
# Breigata 59.91416538461537 10.761711538461537
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Friis’ gate&kommune=301
# Working on: Friis’ gate
# Friis’ gate 59.914550000000006 10.76595
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Heimdalsgata&kommune=301
# Working on: Heimdalsgata
# Heimdalsgata 59.916410769230765 10.764579999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lakkegata&kommune=301
# Working on: Lakkegata
# Lakkegata 59.91781052631579 10.764105263157893
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Motzfeldts gate&kommune=301
# Working on: Motzfeldts gate
# Motzfeldts gate 59.91494594594596 10.765370270270271
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Norbygata&kommune=301
# Working on: Norbygata
# Norbygata 59.913634375000015 10.76454375
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Urtegata&kommune=301
# Working on: Urtegata
# Urtegata 59.9145135135135 10.765164864864863
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Vahls gate&kommune=301
# Working on: Vahls gate
# Vahls gate 59.916133333333335 10.764299999999999
#
#
# Count: 41
# Working on postcode 0188 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0188
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grønland&kommune=301
# Working on: Grønland
# Grønland 59.91311176470589 10.760717647058826
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Olafiagangen&kommune=301
# Working on: Olafiagangen
# Olafiagangen 59.9129 10.759116666666666
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Smalgangen&kommune=301
# Working on: Smalgangen
# Smalgangen 59.91243199999999 10.760562
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tøyenbekken&kommune=301
# Working on: Tøyenbekken
# Tøyenbekken 59.91233571428571 10.762728571428571
#
#
# Count: 42
# Working on postcode 0190 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=0190
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grønlandsleiret&kommune=301
# Working on: Grønlandsleiret
# Grønlandsleiret 59.911265384615376 10.766240384615383
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hollendergata&kommune=301
# Working on: Hollendergata
# Hollendergata 59.91006153846153 10.76692307692308
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Mandalls gate&kommune=301
# Working on: Mandalls gate
# Mandalls gate 59.91200576923076 10.763728846153843
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Margit Hansens gate&kommune=301
# Working on: Margit Hansens gate
# Margit Hansens gate 59.911950000000004 10.76485
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Norbygata&kommune=301
# Working on: Norbygata
# Norbygata 59.913634375000015 10.76454375
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Platous gate&kommune=301
# Working on: Platous gate
# Platous gate 59.91213333333333 10.765951515151512
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rubina Ranas gate&kommune=301
# Working on: Rubina Ranas gate
# ...
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Geviret&kommune=301
# Working on: Geviret
# Geviret 59.832418556700986 10.835264948453604
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grevlinglia&kommune=301
# Working on: Grevlinglia
# Grevlinglia 59.83125781249999 10.831434375
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Rådyrlia&kommune=301
# Working on: Rådyrlia
# Rådyrlia 59.834888372093026 10.830255813953487
#
#
# Count: 427
# Working on postcode 1271 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1271
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bjørnåsveien&kommune=301
# Working on: Bjørnåsveien
# Bjørnåsveien 59.8288328358209 10.832429850746264
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Seterbråtveien&kommune=301
# Working on: Seterbråtveien
# Seterbråtveien 59.82597999999998 10.833987142857135
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Thorn Dønhaugs vei&kommune=301
# Working on: Thorn Dønhaugs vei
# Thorn Dønhaugs vei 59.82560588235294 10.831247058823532
#
#
# Count: 428
# Working on postcode 1272 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1272
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bjørnåsveien&kommune=301
# Working on: Bjørnåsveien
# Bjørnåsveien 59.8288328358209 10.832429850746264
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Mina Beiteplukksvei&kommune=301
# Working on: Mina Beiteplukksvei
# Mina Beiteplukksvei 59.82953921568636 10.834608496732038
#
#
# Count: 429
# Working on postcode 1273 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1273
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hans Steinpukkers vei&kommune=301
# Working on: Hans Steinpukkers vei
# Hans Steinpukkers vei 59.82219090909091 10.835918181818183
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Meklenborglia&kommune=301
# Working on: Meklenborglia
# Meklenborglia 59.81834761904762 10.836390476190477
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Meklenborgveien&kommune=301
# Working on: Meklenborgveien
# Meklenborgveien 59.821485185185196 10.83525925925926
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Prestlia&kommune=301
# Working on: Prestlia
# Prestlia 59.820768750000006 10.8364625
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Snipemyrlia&kommune=301
# Working on: Snipemyrlia
# Snipemyrlia 59.81748928571428 10.837671428571428
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Snipemyrveien&kommune=301
# Working on: Snipemyrveien
# Snipemyrveien 59.819965 10.837430000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tørtbergveien&kommune=301
# Working on: Tørtbergveien
# Tørtbergveien 59.82334166666667 10.834883333333332
#
#
# Count: 430
# Working on postcode 1274 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1274
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grantunet&kommune=301
# Working on: Grantunet
# Grantunet 59.82542105263157 10.840176315789481
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Langteigåsen&kommune=301
# Working on: Langteigåsen
# Langteigåsen 59.81884929577467 10.839554929577469
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Meklenborgåsen&kommune=301
# Working on: Meklenborgåsen
# Meklenborgåsen 59.823888679245265 10.837518867924526
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Trollstien&kommune=301
# Working on: Trollstien
# Trollstien 59.8177 10.8407
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Ødegårdsveien&kommune=301
# Working on: Ødegårdsveien
# Ødegårdsveien 59.81729000000001 10.839343333333334
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Åslandhellinga&kommune=301
# Working on: Åslandhellinga
# Åslandhellinga 59.82340027777778 10.841385833333327
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Åslandkroken&kommune=301
# Working on: Åslandkroken
# Åslandkroken 59.821229032258074 10.84287741935484
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Åslandveien&kommune=301
# Working on: Åslandveien
# Åslandveien 59.81892040816328 10.84297959183673
#
#
# Count: 431
# Working on postcode 1275 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1275
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Beverkollen&kommune=301
# Working on: Beverkollen
# Beverkollen 59.82019852941176 10.839444117647062
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Granbergstubben&kommune=301
# Working on: Granbergstubben
# Granbergstubben 59.82748181818184 10.837429370629385
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nyjordeveien&kommune=301
# Working on: Nyjordeveien
# Nyjordeveien 59.83078620689656 10.838265517241382
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nyjordstubben&kommune=301
# Working on: Nyjordstubben
# Nyjordstubben 59.82872890173412 10.840268208092484
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sisikveien&kommune=301
# Working on: Sisikveien
# Sisikveien 59.8223489361702 10.837631914893617
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Slimeveien&kommune=301
# Working on: Slimeveien
# Slimeveien 59.8334142857143 10.837757142857143
#
#
# Count: 432
# Working on postcode 1278 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1278
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Klemetsrudveien&kommune=301
# Working on: Klemetsrudveien
# Klemetsrudveien 59.84178000000001 10.83606
#
#
# Count: 433
# Working on postcode 1279 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1279
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bilittkroken&kommune=301
# Working on: Bilittkroken
# Bilittkroken 59.84694999999999 10.839224999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brattlistubben&kommune=301
# Working on: Brattlistubben
# Brattlistubben 59.844139999999996 10.84457
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brennagrenda&kommune=301
# Working on: Brennagrenda
# Brennagrenda 59.84758965517241 10.843813793103452
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brennastubben&kommune=301
# Working on: Brennastubben
# Brennastubben 59.84821739130434 10.842469565217394
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brennaveien&kommune=301
# Working on: Brennaveien
# Brennaveien 59.84534411764705 10.844358823529415
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Enebakkveien&kommune=301
# Working on: Enebakkveien
# Enebakkveien 59.87668538283053 10.822499999999994
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Gamle Brennavei&kommune=301
# Working on: Gamle Brennavei
# Gamle Brennavei 59.84576111111111 10.84211111111111
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Langretta&kommune=301
# Working on: Langretta
# Langretta 59.84388000000001 10.84262
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pasoplia&kommune=301
# Working on: Pasoplia
# Pasoplia 59.841895833333325 10.844170833333335
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pasopsvingen&kommune=301
# Working on: Pasopsvingen
# Pasopsvingen 59.84220666666668 10.844233333333333
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Pasopveien&kommune=301
# Working on: Pasopveien
# Pasopveien 59.84385333333333 10.846777777777778
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Smalåkeren&kommune=301
# Working on: Smalåkeren
# Smalåkeren 59.84697272727272 10.841009090909093
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sørliveien&kommune=301
# Working on: Sørliveien
# Sørliveien 59.840071428571434 10.849985714285713
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Tjernlia&kommune=301
# Working on: Tjernlia
# Tjernlia 59.83379491525423 10.847162711864408
#
#
# Count: 434
# Working on postcode 1281 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1281
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Blakkens vei&kommune=301
# Working on: Blakkens vei
# Blakkens vei 59.84161840000001 10.830037599999997
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Brunas vei&kommune=301
# Working on: Brunas vei
# Brunas vei 59.84407850467287 10.828714018691588
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Helga Vaneks vei&kommune=301
# Working on: Helga Vaneks vei
# Helga Vaneks vei 59.848796 10.831355999999998
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lofsrudhøgda&kommune=301
# Working on: Lofsrudhøgda
# Lofsrudhøgda 59.84774874371858 10.826701507537683
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lofsrudveien&kommune=301
# Working on: Lofsrudveien
# Lofsrudveien 59.84665 10.829525
#
#
# Count: 435
# Working on postcode 1283 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1283
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hans Breiens vei&kommune=301
# Working on: Hans Breiens vei
# Hans Breiens vei 59.852000000000004 10.82525
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Jordstjerneveien&kommune=301
# Working on: Jordstjerneveien
# Jordstjerneveien 59.847452380952376 10.819048917748935
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Marta Steinsviks vei&kommune=301
# Working on: Marta Steinsviks vei
# Marta Steinsviks vei 59.85391844660192 10.822736893203885
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Mortensrudveien&kommune=301
# Working on: Mortensrudveien
# Mortensrudveien 59.84841453488374 10.823973837209296
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stenbråtveien&kommune=301
# Working on: Stenbråtveien
# Stenbråtveien 59.85667218045108 10.821472180451128
#
#
# Count: 436
# Working on postcode 1284 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1284
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Gamle Bygdevei&kommune=301
# Working on: Gamle Bygdevei
# Gamle Bygdevei 59.85662129277564 10.825328517110275
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Granebakken&kommune=301
# Working on: Granebakken
# Granebakken 59.856661855670104 10.828198969072162
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Olasrudveien&kommune=301
# Working on: Olasrudveien
# Olasrudveien 59.85390469798655 10.82946040268457
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stenbråtveien&kommune=301
# Working on: Stenbråtveien
# Stenbråtveien 59.85667218045108 10.821472180451128
#
#
# Count: 437
# Working on postcode 1285 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1285
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Avlangruds vei&kommune=301
# Working on: Avlangruds vei
# Avlangruds vei 59.851215384615394 10.839284615384615
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bjørn Lies vei&kommune=301
# Working on: Bjørn Lies vei
# Bjørn Lies vei 59.85326666666667 10.84036
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dalsløkka&kommune=301
# Working on: Dalsløkka
# Dalsløkka 59.85142727272727 10.840372727272726
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dalsroa&kommune=301
# Working on: Dalsroa
# Dalsroa 59.84906944444445 10.839641666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dalssvingen&kommune=301
# Working on: Dalssvingen
# Dalssvingen 59.85087187500002 10.841468749999997
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dalsåsen&kommune=301
# Working on: Dalsåsen
# Dalsåsen 59.85505882352941 10.840839705882354
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Enebakkveien&kommune=301
# Working on: Enebakkveien
# Enebakkveien 59.87668538283053 10.822499999999994
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Nordre Dals vei&kommune=301
# Working on: Nordre Dals vei
# Nordre Dals vei 59.85561764705883 10.838079411764706
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Oscar Dahls vei&kommune=301
# Working on: Oscar Dahls vei
# Oscar Dahls vei 59.85369787234044 10.837444680851062
#
#
# Count: 438
# Working on postcode 1286 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1286
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Bispeluelia&kommune=301
# Working on: Bispeluelia
# Bispeluelia 59.847281666666696 10.81621666666667
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Kantarellen terrasse&kommune=301
# Working on: Kantarellen terrasse
# Kantarellen terrasse 59.848844680851066 10.812765957446812
#
#
# Count: 439
# Working on postcode 1290 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1290
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Dølerudveien&kommune=301
# Working on: Dølerudveien
# Dølerudveien 59.8353 10.874299999999998
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Enebakkveien&kommune=301
# Working on: Enebakkveien
# Enebakkveien 59.87668538283053 10.822499999999994
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Godheimveien&kommune=301
# Working on: Godheimveien
# Godheimveien 59.833312500000005 10.861275
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Grønmoveien&kommune=301
# Working on: Grønmoveien
# Grønmoveien 59.83352857142857 10.862571428571428
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Hanåveien&kommune=301
# Working on: Hanåveien
# Hanåveien 59.824911111111106 10.893288888888888
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stensrudåsveien&kommune=301
# Working on: Stensrudåsveien
# Stensrudåsveien 59.82169999999999 10.863375000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Øverliveien&kommune=301
# Working on: Øverliveien
# Øverliveien 59.833660655737646 10.850819672131147
#
#
# Count: 440
# Working on postcode 1291 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1291
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Maurtuveien&kommune=301
# Working on: Maurtuveien
# Maurtuveien 59.8253 10.851233333333337
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Sluttstykket&kommune=301
# Working on: Sluttstykket
# Sluttstykket 59.8184 10.8503
#
#
# Count: 441
# Working on postcode 1294 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1294
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Enebakkveien&kommune=301
# Working on: Enebakkveien
# Enebakkveien 59.87668538283053 10.822499999999994
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stensrudlia&kommune=301
# Working on: Stensrudlia
# Stensrudlia 59.82212 10.863959999999999
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stensrudåsveien&kommune=301
# Working on: Stensrudåsveien
# Stensrudåsveien 59.82169999999999 10.863375000000001
#
#
# Count: 442
# Working on postcode 1295 OSLO...
# https://www.erikbolstad.no/postnummer-koordinatar/?postnummer=1295
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Delebekken&kommune=301
# Working on: Delebekken
# Delebekken 59.81603913043478 10.877926086956522
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Enebakkveien&kommune=301
# Working on: Enebakkveien
# Enebakkveien 59.87668538283053 10.822499999999994
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lille Stensrud&kommune=301
# Working on: Lille Stensrud
# Lille Stensrud 59.8207 10.876750000000001
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Lyberget&kommune=301
# Working on: Lyberget
# Lyberget 59.816050000000004 10.87385
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Siggerudveien&kommune=301
# Working on: Siggerudveien
# Siggerudveien 59.8166142857143 10.883985714285714
#
# https://www.erikbolstad.no/postnummer-koordinatar/veg.php?veg=Stensrudsvingen&kommune=301
# Working on: Stensrudsvingen
# Stensrudsvingen 59.818644444444445 10.870699999999998

# %%
#Create backup version of the dictionary created above, just in case
midStreetDict_backUp = midStreetDict

#Check backup dictionary formed
for k,v in midStreetDict_backUp.items():
    print(k,v)

# %%
#Check a small sample of streets
streetDataSmall = pd.DataFrame.from_dict(combined, orient='index')

#Reset row index to numerical values
streetDataSmall.reset_index(inplace = True)

#Change column names
streetDataSmall.columns.values[0:] = ['StreetAddress','Latitude','Longitude']

#View first 5 rows
streetDataSmall.head()
# Out:
#    StreetAddress Latitude Longitude
# 0  Rådhusgata 11  59.9094   10.7434
# 1   Rådhusgata 2  59.9085   10.7462
# 2  Rådhusgata 7B  59.9092   10.7441
# 3  Rådhusgata 20  59.9095   10.7421
# 4   Rådhusgata 5  59.9089   10.7455

# %%
#Arrange above df in ascending order of address
#streetDataSmall.sort_values('StreetAddress', ascending= True, axis = 0)
from natsort import order_by_index, index_natsorted
streetDataSmall.reindex(index=order_by_index(streetDataSmall.index, index_natsorted(streetDataSmall.StreetAddress))).reset_index()
# Out:
#     index  StreetAddress Latitude Longitude
# 0      31   Vargveien 1A  59.8721   10.7764
# 1      29   Vargveien 1B  59.8721   10.7764
# 2       3   Vargveien 1C  59.8719   10.7765
# 3      46   Vargveien 1D  59.8718   10.7765
# 4      18   Vargveien 1E  59.8716   10.7763
# 5      24   Vargveien 1F  59.8714   10.7763
# 6      40   Vargveien 1G  59.8714   10.7762
# 7      42   Vargveien 1H  59.8712   10.7760
# 8      39    Vargveien 2  59.8712   10.7767
# 9      38   Vargveien 3A  59.8707   10.7753
# 10     32   Vargveien 3B  59.8706   10.7756
# 11     28   Vargveien 3C  59.8710   10.7755
# 12     14    Vargveien 4  59.8709   10.7764
# 13     20    Vargveien 5  59.8705   10.7752
# 14     19    Vargveien 6  59.8707   10.7764
# 15      7    Vargveien 7  59.8702   10.7750
# 16     30    Vargveien 8  59.8704   10.7762
# 17     11    Vargveien 9  59.8700   10.7746
# 18      6   Vargveien 10  59.8697   10.7751
# 19     23   Vargveien 11  59.8702   10.7744
# 20     16  Vargveien 11B  59.8703   10.7741
# 21     27   Vargveien 13  59.8704   10.7738
# 22     37   Vargveien 14  59.8699   10.7736
# 23     10  Vargveien 15A  59.8706   10.7729
# 24      8  Vargveien 15B  59.8706   10.7732
# 25     41  Vargveien 16A  59.8702   10.7727
# 26      0  Vargveien 16B  59.8702   10.7726
# 27     45  Vargveien 16C  59.8702   10.7727
# 28     35   Vargveien 17  59.8705   10.7726
# 29     33  Vargveien 18A  59.8702   10.7722
# 30     25  Vargveien 18B  59.8702   10.7720
# 31     15   Vargveien 19  59.8704   10.7718
# 32     12   Vargveien 20  59.8700   10.7717
# 33     34  Vargveien 20B  59.8699   10.7718
# 34     22   Vargveien 21  59.8703   10.7715
# 35     36  Vargveien 22A  59.8697   10.7716
# 36      5  Vargveien 22B  59.8698   10.7714
# 37     43   Vargveien 23  59.8701   10.7710
# 38     47   Vargveien 24  59.8696   10.7714
# 39     17   Vargveien 25  59.8698   10.7706
# 40     13   Vargveien 26  59.8695   10.7708
# 41     26   Vargveien 27  59.8696   10.7703
# 42      2   Vargveien 28  59.8693   10.7704
# 43     21   Vargveien 29  59.8693   10.7698
# 44      9   Vargveien 30  59.8690   10.7701
# 45      1   Vargveien 31  59.8690   10.7691
# 46      4   Vargveien 32  59.8688   10.7697
# 47     44   Vargveien 34  59.8686   10.7693

# %%
from natsort import natsorted
natsorted((k,v) for k,v in combined.items())#Sorts on K, and if you want v with it, bracket them together
# Out:
# [('Stensrudsvingen 2', ('59.8192', ' 10.8725')),
#  ('Stensrudsvingen 4', ('59.8190', ' 10.8723')),
#  ('Stensrudsvingen 5', ('59.8205', ' 10.8700')),
#  ('Stensrudsvingen 6', ('59.8174', ' 10.8703')),
#  ('Stensrudsvingen 7', ('59.8193', ' 10.8703')),
#  ('Stensrudsvingen 8', ('59.8171', ' 10.8703')),
#  ('Stensrudsvingen 10', ('59.8185', ' 10.8707')),
#  ('Stensrudsvingen 12', ('59.8183', ' 10.8702')),
#  ('Stensrudsvingen 14', ('59.8185', ' 10.8697'))]

# %%
#Obtain first and last address
#Find length of list
listLen = len(natsorted((k,v) for k,v in combined.items()))
#print(listLen)

count = 0
for i in natsorted((k,v) for k,v in combined.items()):
    count = count+1
    if count == 1:
        coords1 = i[1][0], i[1][1]#Can index within a list of a list in python
        print(coords1)#Geopy distance estimator takes in tuple
    elif count == listLen:
        coords2 = i[1][0], i[1][1]
        print(coords2)
# Out:
# ('59.8192', ' 10.8725')
# ('59.8185', ' 10.8697')

# %%
import geopy.distance

coords_1 = (52.2296756, 21.0122287)
print(type(coords_1))
coords_2 = (52.406374, 16.9251681)
print(type(coords_2))

#print (geopy.distance.vincenty(coords_1, coords_2).km) #Vincenty is deprecated, the either of the 2 below
#print (geopy.distance.geodesic(coords_1, coords_2).km)
#print (geopy.distance.distance(coords_1, coords_2).km) #Default
print( geopy.distance.distance(coords1, coords2).m)
# Out:
# <class 'tuple'>
# <class 'tuple'>
# 175.3858930348763

# %%
midStreetDict
# Out:
# {}

# %%
streetData = pd.DataFrame.from_dict(midStreetDict, orient= 'index')

#Reset index
streetData.reset_index(inplace = True)

#Rename columns
streetData.columns.values[0:] = ['Street','MidLatitude','MidLongitude']
streetData.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6fa32455405a> in <module>
#       5
#       6 #Rename columns
# ----> 7 streetData.columns.values[0:] = ['Street','MidLatitude','MidLongitude']
#       8 streetData.head()
#
# ValueError: cannot copy sequence with size 3 to array axis with dimension 1

# %%
streetData.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1b9953b5bba1> in <module>
# ----> 1 streetData.shape
#
# NameError: name 'streetData' is not defined

# %%
streetData.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-dfcfd6422dd4> in <module>
# ----> 1 streetData.isnull().sum()
#
# NameError: name 'streetData' is not defined
